# %%
# %pylab inline
import sys
sys.dont_write_bytecode = True
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from data import train_Sequence, valid_Sequence
# Out:
# Using TensorFlow backend.

# %%
images, labels = train_Sequence[5]

# %%
images = (images + 1) / 2

# %%
imshow(images[3])

# %%
imshow(labels[3, ..., 0])

# %%
images[3].shape
# Out:
# (1024, 1024, 3)

# %%
from skimage import io

# %%
import cv2
def preprocess(img_path):
    img = io.imread(img_path)
    img = cv2.resize(img, (1024, 1024))
    img = img.astype(np.float32)
    img = img /127.5
    img = img - 1
    return img
tt = preprocess("../inference/output/patchs/stage2/test/0156_1_1565791505_73/3000_6000_3000_6000.png")

# %%
from skimage import exposure
tt = (tt + 1) /2.
gamma_corrected = exposure.adjust_gamma(tt, 2)
logarithmic_corrected = exposure.adjust_log(tt, 1)

# %%
imshow(logarithmic_corrected)
